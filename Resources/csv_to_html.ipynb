# %%
import pandas as pd

# %%
file_to_load = 'cities.csv'

# %%
cities_df = pd.read_csv(file_to_load)

# %%
cities_df = cities_df.set_index('City_ID')

# %%
cities_df
# Out:
#                    City      Lat       Lng  Max_Temp  Humidity  Cloudiness  \
# City_ID
# 0              hermanus -34.4187   19.2345     64.99        94          98
# 1        cabo san lucas  22.8909 -109.9124     64.40        59          20
# 2                avarua -21.2078 -159.7750     82.40        74           7
# 3              libohove  40.0311   20.2631     59.00       100          20
# 4        saint-philippe -21.3585   55.7679     84.20        70           0
# ...                 ...      ...       ...       ...       ...         ...
# 575             baghdad  33.3406   44.4009     55.40        94          75
# 576         kapuskasing  49.4169  -82.4331    -11.20        77          30
# 577              ararat  39.8317   44.7049     28.40        93           0
# 578                jalu  29.0331   21.5482     55.85        47           0
# 579               kutum  14.2000   24.6667     44.31        57          16
#
#          Wind_Speed Country        Date
# City_ID
# ...

# %%
cities_df.to_html('cities.html', index = True, header = True)
